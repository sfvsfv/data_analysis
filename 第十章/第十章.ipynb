# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...

# %% [markdown]
# ## 10.2  快速入门

# %%
import pandas as pd

# %%
data = {
    '苹果': [300,320,310,340], 
    '香蕉': [310,315,330,345]
}

# %%
fruit=pd.DataFrame(data)

fruit
# Out:
#     苹果   香蕉
# 0  300  310
# 1  320  315
# 2  310  330
# 3  340  345

# %%
fruit=pd.DataFrame(data,index=['一月','二月','三月','四月'])

fruit
# Out:
#      苹果   香蕉
# 一月  300  310
# 二月  320  315
# 三月  310  330
# 四月  340  345

# %%
data = {
    '日期':['一月','二月','三月','四月'],
    '苹果': [300,320,310,340], 
    '香蕉': [310,315,330,345]
}
fruit=pd.DataFrame(data)

fruit
# Out:
#    日期   苹果   香蕉
# 0  一月  300  310
# 1  二月  320  315
# 2  三月  310  330
# 3  四月  340  345

# %%
fruit.set_index('日期',inplace = True)

print(fruit)
# Out:
#      苹果   香蕉
# 日期
# 一月  300  310
# 二月  320  315
# 三月  310  330
# 四月  340  345

# %%
fruit.loc['二月']
# Out:
# 苹果    320
# 香蕉    315
# Name: 二月, dtype: int64

# %%
fruit.loc['四月']
# Out:
# 苹果    340
# 香蕉    345
# Name: 四月, dtype: int64

# %%
fruit['二月':'四月']
# Out:
#      苹果   香蕉
# 日期
# 二月  320  315
# 三月  310  330
# 四月  340  345

# %%
fruit.loc['三月','香蕉']
# Out:
# 330

# %%
fruit.loc['二月':'四月','苹果':'香蕉']
# Out:
#      苹果   香蕉
# 日期
# 二月  320  315
# 三月  310  330
# 四月  340  345

# %% [markdown]
# ## 读取文件

# %%
df = pd.read_csv('test.csv',index_col=0,encoding='utf-8')

df
# Out:
#        apple  banana  peach
# month
# Jan      300     310    190
# Feb      320     315    264
# Mar      310     330    247
# Apr      340     345    312
# May      360     350    285
# Jun      345     326    346
# Jul      389     378    145
# Aug      410     416    265
# Sep      360     326    218
# Oct      278     342    312
# Nov      236     259    170
# Dec      320     298    256

# %%
# 写入数据到csv

df.to_csv('test2.csv')

# %%
# 写入数据到excel
df.to_excel('test3.xlsx')

# %% [markdown]
# ## 查看数据

# %%
df.head()
# Out:
#        apple  banana  peach
# month
# Jan      300     310    190
# Feb      320     315    264
# Mar      310     330    247
# Apr      340     345    312
# May      360     350    285

# %%
df.tail()
# Out:
#        apple  banana  peach
# month
# Aug      410     416    265
# Sep      360     326    218
# Oct      278     342    312
# Nov      236     259    170
# Dec      320     298    256

# %%
df.index
# Out:
# Index(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct',
#        'Nov', 'Dec'],
#       dtype='object', name='month')

# %%
df.describe()
# Out:
#             apple      banana       peach
# count   12.000000   12.000000   12.000000
# mean   330.666667  332.916667  250.833333
# std     47.711888   39.414945   60.779532
# min    236.000000  259.000000  145.000000
# 25%    307.500000  313.750000  211.000000
# 50%    330.000000  328.000000  260.000000
# 75%    360.000000  346.250000  291.750000
# max    410.000000  416.000000  346.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, Jan to Dec
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   apple   12 non-null     int64
#  1   banana  12 non-null     int64
#  2   peach   12 non-null     int64
# dtypes: int64(3)
# memory usage: 384.0+ bytes

# %% [markdown]
# ## 10.3 索引选择分配

# %% [markdown]
# ## 列索引

# %%
df.apple
# Out:
# month
# Jan    300
# Feb    320
# Mar    310
# Apr    340
# May    360
# Jun    345
# Jul    389
# Aug    410
# Sep    360
# Oct    278
# Nov    236
# Dec    320
# Name: apple, dtype: int64

# %%
df.banana
# Out:
# month
# Jan    310
# Feb    315
# Mar    330
# Apr    345
# May    350
# Jun    326
# Jul    378
# Aug    416
# Sep    326
# Oct    342
# Nov    259
# Dec    298
# Name: banana, dtype: int64

# %%
df.peach
# Out:
# month
# Jan    190
# Feb    264
# Mar    247
# Apr    312
# May    285
# Jun    346
# Jul    145
# Aug    265
# Sep    218
# Oct    312
# Nov    170
# Dec    256
# Name: peach, dtype: int64

# %%
df['apple']
# Out:
# month
# Jan    300
# Feb    320
# Mar    310
# Apr    340
# May    360
# Jun    345
# Jul    389
# Aug    410
# Sep    360
# Oct    278
# Nov    236
# Dec    320
# Name: apple, dtype: int64

# %%
df['apple'][4]
# Out:
# 360

# %%
df['apple'][2:5]
# Out:
# month
# Mar    310
# Apr    340
# May    360
# Name: apple, dtype: int64

# %%
df[['apple','peach']]
# Out:
#        apple  peach
# month
# Jan      300    190
# Feb      320    264
# Mar      310    247
# Apr      340    312
# May      360    285
# Jun      345    346
# Jul      389    145
# Aug      410    265
# Sep      360    218
# Oct      278    312
# Nov      236    170
# Dec      320    256

# %% [markdown]
# ## 行索引

# %%
df[1:7]
# Out:
#        apple  banana  peach
# month
# Feb      320     315    264
# Mar      310     330    247
# Apr      340     345    312
# May      360     350    285
# Jun      345     326    346
# Jul      389     378    145

# %%
df.iloc[1:7]
# Out:
#        apple  banana  peach
# month
# Feb      320     315    264
# Mar      310     330    247
# Apr      340     345    312
# May      360     350    285
# Jun      345     326    346
# Jul      389     378    145

# %%
df[['apple','banana','peach']][2:6]
# Out:
#        apple  banana  peach
# month
# Mar      310     330    247
# Apr      340     345    312
# May      360     350    285
# Jun      345     326    346

# %%
df.iloc[2:6][['apple','banana','peach']]
# Out:
#        apple  banana  peach
# month
# Mar      310     330    247
# Apr      340     345    312
# May      360     350    285
# Jun      345     326    346

# %%
df
# Out:
#        apple  banana  peach
# month
# Jan      300     310    190
# Feb      320     315    264
# Mar      310     330    247
# Apr      340     345    312
# May      360     350    285
# Jun      345     326    346
# Jul      389     378    145
# Aug      410     416    265
# Sep      360     326    218
# Oct      278     342    312
# Nov      236     259    170
# Dec      320     298    256

# %%
df.iloc[2,1]
# Out:
# 330

# %%
df.iloc[2:6,1:]
# Out:
#        banana  peach
# month
# Mar       330    247
# Apr       345    312
# May       350    285
# Jun       326    346

# %% [markdown]
# ## 条件筛选

# %%
df[df['apple']>320]
# Out:
#        apple  banana  peach
# month
# Apr      340     345    312
# May      360     350    285
# Jun      345     326    346
# Jul      389     378    145
# Aug      410     416    265
# Sep      360     326    218

# %%
df[(df['apple']>320) & (df['peach']<250)]
# Out:
#        apple  banana  peach
# month
# Jul      389     378    145
# Sep      360     326    218

# %%
df.sort_values(by='apple',ascending=False)
# Out:
#        apple  banana  peach
# month
# Aug      410     416    265
# Jul      389     378    145
# May      360     350    285
# Sep      360     326    218
# Jun      345     326    346
# Apr      340     345    312
# Feb      320     315    264
# Dec      320     298    256
# Mar      310     330    247
# Jan      300     310    190
# Oct      278     342    312
# Nov      236     259    170

# %%
df.sort_values(by='peach',ascending=True) #第二个参数可省略
# Out:
#        apple  banana  peach
# month
# Jul      389     378    145
# Nov      236     259    170
# Jan      300     310    190
# Sep      360     326    218
# Mar      310     330    247
# Dec      320     298    256
# Feb      320     315    264
# Aug      410     416    265
# May      360     350    285
# Apr      340     345    312
# Oct      278     342    312
# Jun      345     326    346

# %% [markdown]
# ###  10.4.6 数据分组

# %%
import pandas as pd


data = {'name':['张三', '王宝', '小明', '小强',
                '小红', '小强'],
        'age':[20, 22, 23, 18,
            19, 24],
         'address':['上海', '北京', '成都', '广东',
                '西安', '福建'],
        'interest':['学习', '游戏', '锻炼', '学习',
                   '编程','唱歌']
                    }


# 字典转为对象
df = pd.DataFrame(data)

print(df)
# Out:
#   name  age address interest
# 0   张三   20      上海       学习
# 1   王宝   22      北京       游戏
# 2   小明   23      成都       锻炼
# 3   小强   18      广东       学习
# 4   小红   19      西安       编程
# 5   小强   24      福建       唱歌

# %%
df.groupby('address').groups
# Out:
# {'上海': [0], '北京': [1], '广东': [3], '成都': [2], '福建': [5], '西安': [4]}

# %%
df.groupby('interest').groups
# Out:
# {'唱歌': [5], '学习': [0, 3], '游戏': [1], '编程': [4], '锻炼': [2]}

# %%
df.groupby(['address']).sum()
# Out:
#          age
# address
# 上海        20
# 北京        22
# 广东        18
# 成都        23
# 福建        24
# 西安        19

# %%
df.groupby(['address'],sort = True).sum()
# Out:
#          age
# address
# 上海        20
# 北京        22
# 广东        18
# 成都        23
# 福建        24
# 西安        19

# %%
grp = df.groupby('name')
grp.get_group('小明')
# Out:
#   name  age address interest
# 2   小明   23      成都       锻炼

# %%
grp = df.groupby(['name','address'])
grp.get_group(('小明','成都'))
# Out:
#   name  age address interest
# 2   小明   23      成都       锻炼

# %% [markdown]
# ## 数据增删

# %%
import pandas as pd


data = {'name':['张三', '王宝', '小明', '小强',
                '小红', '小强'],
        'age':[20, 22, 23, 18,
            19, 24],
         'address':['上海', '北京', '成都', '广东',
                '西安', '福建'],
        'interest':['学习', '游戏', '锻炼', '学习',
                   '编程','唱歌']
                    }


# 字典转为对象
df = pd.DataFrame(data)

df
# Out:
#   name  age address interest
# 0   张三   20      上海       学习
# 1   王宝   22      北京       游戏
# 2   小明   23      成都       锻炼
# 3   小强   18      广东       学习
# 4   小红   19      西安       编程
# 5   小强   24      福建       唱歌

# %%
df.loc[6]=['王大',21,'杭州','python']

df
# Out:
#   name  age address interest
# 0   张三   20      上海       学习
# 1   王宝   22      北京       游戏
# 2   小明   23      成都       锻炼
# 3   小强   18      广东       学习
# 4   小红   19      西安       编程
# 5   小强   24      福建       唱歌
# 6   王大   21      杭州   python

# %%
df['学历']='本科'
df
# Out:
#   name  age address interest  学历
# 0   张三   20      上海       学习  本科
# 1   王宝   22      北京       游戏  本科
# 2   小明   23      成都       锻炼  本科
# 3   小强   18      广东       学习  本科
# 4   小红   19      西安       编程  本科
# 5   小强   24      福建       唱歌  本科
# 6   王大   21      杭州   python  本科

# %%
df['学历']=['本科','研究生','本科','研究生','本科','研究生','研究生']
df
# Out:
#   name  age address interest   学历
# 0   张三   20      上海       学习   本科
# 1   王宝   22      北京       游戏  研究生
# 2   小明   23      成都       锻炼   本科
# 3   小强   18      广东       学习  研究生
# 4   小红   19      西安       编程   本科
# 5   小强   24      福建       唱歌  研究生
# 6   王大   21      杭州   python  研究生

# %%
df.pop('age')
df
# Out:
#   name address interest   学历
# 0   张三      上海       学习   本科
# 1   王宝      北京       游戏  研究生
# 2   小明      成都       锻炼   本科
# 3   小强      广东       学习  研究生
# 4   小红      西安       编程   本科
# 5   小强      福建       唱歌  研究生
# 6   王大      杭州   python  研究生

# %%
df=df.drop(columns=['interest'])
df
# Out:
#   name address   学历
# 0   张三      上海   本科
# 1   王宝      北京  研究生
# 2   小明      成都   本科
# 3   小强      广东  研究生
# 4   小红      西安   本科
# 5   小强      福建  研究生
# 6   王大      杭州  研究生

# %%
df=df.drop(['address'],axis=1) # axis=1表示删除列
df
# Out:
#   name   学历
# 0   张三   本科
# 1   王宝  研究生
# 2   小明   本科
# 3   小强  研究生
# 4   小红   本科
# 5   小强  研究生
# 6   王大  研究生

# %% [markdown]
# ## 18.4 数据拼接

# %%
import pandas as pd

gold = pd.read_csv('GOLD.csv',encoding='utf-8')
gold.head()
# Out:
#         Date     GOLD
# 0  2016/9/12  1324.60
# 1  2016/9/13  1323.65
# 2  2016/9/14  1321.75
# 3  2016/9/15  1310.80
# 4  2016/9/16  1308.35

# %%
bt = pd.read_csv('BT.csv',encoding='utf-8')
bt.head()
# Out:
#         Date      BT
# 0  2016/9/12  609.67
# 1  2016/9/13  610.92
# 2  2016/9/14  608.82
# 3  2016/9/15  610.38
# 4  2016/9/16  609.11

# %%
result = pd.merge(gold,bt,on='Date')

result
# Out:
#            Date     GOLD        BT
# 0     2016/9/12  1324.60    609.67
# 1     2016/9/13  1323.65    610.92
# 2     2016/9/14  1321.75    608.82
# 3     2016/9/15  1310.80    610.38
# 4     2016/9/16  1308.35    609.11
# ...         ...      ...       ...
# 1820   2021/9/6  1821.60  51769.06
# 1821   2021/9/7  1802.15  52677.40
# 1822   2021/9/8  1786.00  46809.17
# 1823   2021/9/9  1788.25  46078.38
# 1824  2021/9/10  1794.60  46368.69
#
# [1825 rows x 3 columns]

# %% [markdown]
# ## 统计分析

# %% [markdown]
# ### 相关性分析

# %%
result.corr()
# Out:
#           GOLD        BT
# GOLD  1.000000  0.649429
# BT    0.649429  1.000000

# %%
result.corr('kendall')
# Out:
#           GOLD        BT
# GOLD  1.000000  0.558762
# BT    0.558762  1.000000

# %%
result.corr('spearman')
# Out:
#           GOLD        BT
# GOLD  1.000000  0.786181
# BT    0.786181  1.000000

# %% [markdown]
# ### 变化率

# %%
df = pd.read_csv('test.csv',index_col=0,encoding='utf-8')

df
# Out:
#        apple  banana  peach
# month
# Jan      300     310    190
# Feb      320     315    264
# Mar      310     330    247
# Apr      340     345    312
# May      360     350    285
# Jun      345     326    346
# Jul      389     378    145
# Aug      410     416    265
# Sep      360     326    218
# Oct      278     342    312
# Nov      236     259    170
# Dec      320     298    256

# %%
df.pct_change()
# Out:
#           apple    banana     peach
# month
# Jan         NaN       NaN       NaN
# Feb    0.066667  0.016129  0.389474
# Mar   -0.031250  0.047619 -0.064394
# Apr    0.096774  0.045455  0.263158
# May    0.058824  0.014493 -0.086538
# Jun   -0.041667 -0.068571  0.214035
# Jul    0.127536  0.159509 -0.580925
# Aug    0.053985  0.100529  0.827586
# Sep   -0.121951 -0.216346 -0.177358
# Oct   -0.227778  0.049080  0.431193
# Nov   -0.151079 -0.242690 -0.455128
# Dec    0.355932  0.150579  0.505882

# %% [markdown]
# ### 协方差

# %%
df.cov()
# Out:
#               apple       banana        peach
# apple   2276.424242  1579.878788   282.212121
# banana  1579.878788  1553.537879   437.893939
# peach    282.212121   437.893939  3694.151515

# %% [markdown]
# ### 描述统计

# %% [markdown]
# ## 合并

# %%
data1 = {
    '苹果': [300,320,310,340], 
    '香蕉': [310,315,330,345]
}

data2 = {
    '哈密瓜': [274,264,331,215], 
    '桃子': [145,135,210,165]
}

fru1=pd.DataFrame(data1)

fru2=pd.DataFrame(data2)

# %%
frame1=[fru1,fru2]

data3=pd.concat(frame1)
data3
# Out:
#       苹果     香蕉    哈密瓜     桃子
# 0  300.0  310.0    NaN    NaN
# 1  320.0  315.0    NaN    NaN
# 2  310.0  330.0    NaN    NaN
# 3  340.0  345.0    NaN    NaN
# 0    NaN    NaN  274.0  145.0
# 1    NaN    NaN  264.0  135.0
# 2    NaN    NaN  331.0  210.0
# 3    NaN    NaN  215.0  165.0

# %%
data4=fru1.append(fru2)
data4
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10768\2803676489.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data4=fru1.append(fru2)
#       苹果     香蕉    哈密瓜     桃子
# 0  300.0  310.0    NaN    NaN
# 1  320.0  315.0    NaN    NaN
# 2  310.0  330.0    NaN    NaN
# 3  340.0  345.0    NaN    NaN
# 0    NaN    NaN  274.0  145.0
# 1    NaN    NaN  264.0  135.0
# 2    NaN    NaN  331.0  210.0
# 3    NaN    NaN  215.0  165.0

# %% [markdown]
# ##  10.5 数据清洗

# %% [markdown]
# ### 缺失数据处理

# %%
import pandas as pd
import numpy as np

data = {
    '华为手机': [3000,np.nan,3100,4000], 
    '苹果手机': [5000,5400,7890,8420]
}

phone=pd.DataFrame(data)

phone
# Out:
#      华为手机  苹果手机
# 0  3000.0  5000
# 1     NaN  5400
# 2  3100.0  7890
# 3  4000.0  8420

# %%
phone.isnull()
# Out:
#     华为手机   苹果手机
# 0  False  False
# 1   True  False
# 2  False  False
# 3  False  False

# %%
phone.dropna()
# Out:
#      华为手机  苹果手机
# 0  3000.0  5000
# 2  3100.0  7890
# 3  4000.0  8420

# %%
phone['华为手机'][1]=3050
phone
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10768\2112408472.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phone['华为手机'][1]=3050
#      华为手机  苹果手机
# 0  3000.0  5000
# 1  3050.0  5400
# 2  3100.0  7890
# 3  4000.0  8420

# %% [markdown]
# ##  重复数据处理

# %%
import pandas as pd
import numpy as np

data = {
    'm': ['one','two']*2+['two'], 
    'n': [5,3,5,5,5]
}

fruit=pd.DataFrame(data)

fruit
# Out:
#      m  n
# 0  one  5
# 1  two  3
# 2  one  5
# 3  two  5
# 4  two  5

# %%
fruit.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
fruit.drop_duplicates(['m'])
# Out:
#      m  n
# 0  one  5
# 1  two  3

# %%
fruit.drop_duplicates(['m','n'])
# Out:
#      m  n
# 0  one  5
# 1  two  3
# 3  two  5

# %%
fruit.drop_duplicates(['m','n'],keep='last')
# Out:
#      m  n
# 1  two  3
# 2  one  5
# 4  two  5

# %% [markdown]
# ### 缺失值填充

# %%
import pandas as pd
import numpy as np

data = {
    '华为手机': [3000,np.nan,3100,4000,np.nan], 
    '苹果手机': [5000,5400,7890,np.nan,8450]
}

p=pd.DataFrame(data)

p
# Out:
#      华为手机    苹果手机
# 0  3000.0  5000.0
# 1     NaN  5400.0
# 2  3100.0  7890.0
# 3  4000.0     NaN
# 4     NaN  8450.0

# %%
p.fillna(4000)
# Out:
#      华为手机    苹果手机
# 0  3000.0  5000.0
# 1  4000.0  5400.0
# 2  3100.0  7890.0
# 3  4000.0  4000.0
# 4  4000.0  8450.0

# %%
p.fillna({'华为手机':3500,'苹果手机':6500})
# Out:
#      华为手机    苹果手机
# 0  3000.0  5000.0
# 1  3500.0  5400.0
# 2  3100.0  7890.0
# 3  4000.0  6500.0
# 4  3500.0  8450.0

# %%
p['华为手机'].fillna(p['华为手机'].mean())
# Out:
# 0    3000.000000
# 1    3366.666667
# 2    3100.000000
# 3    4000.000000
# 4    3366.666667
# Name: 华为手机, dtype: float64

# %% [markdown]
# ## 应用案例

# %%
import pandas as pd

df=pd.read_csv('data.csv',encoding='utf-8')

df
# Out:
#    month  apple banana  peach
# 0    Jan  300.0    310  190.0
# 1    Feb  320.0      b  264.0
# 2    Mar  310.0    330  247.0
# 3    Apr    NaN    345    NaN
# 4    May  340.0    350  285.0
# 5    Jun  340.0    326  346.0
# 6    Jul  340.0    378  145.0
# 7    Aug  340.0    416  265.0
# 8    Sep  340.0    NaN  218.0
# 9    Oct  340.0    342  312.0
# 10   Nov  340.0    259  170.0
# 11   Dec  340.0    298  256.0

# %%
df.dropna()
# Out:
#    month  apple banana  peach
# 0    Jan  300.0    310  190.0
# 1    Feb  320.0      b  264.0
# 2    Mar  310.0    330  247.0
# 4    May  340.0    350  285.0
# 5    Jun  340.0    326  346.0
# 6    Jul  340.0    378  145.0
# 7    Aug  340.0    416  265.0
# 9    Oct  340.0    342  312.0
# 10   Nov  340.0    259  170.0
# 11   Dec  340.0    298  256.0

# %%
df.fillna('280')
# Out:
#    month  apple banana  peach
# 0    Jan  300.0    310  190.0
# 1    Feb  320.0      b  264.0
# 2    Mar  310.0    330  247.0
# 3    Apr    280    345    280
# 4    May  340.0    350  285.0
# 5    Jun  340.0    326  346.0
# 6    Jul  340.0    378  145.0
# 7    Aug  340.0    416  265.0
# 8    Sep  340.0    280  218.0
# 9    Oct  340.0    342  312.0
# 10   Nov  340.0    259  170.0
# 11   Dec  340.0    298  256.0

# %%
df['apple'].fillna(df['apple'].mean(),inplace=True )

# %%
df['peach'].fillna(df['peach'].mean(),inplace=True )

# %%
print(df)
# Out:
#    month       apple banana       peach
# 0    Jan  300.000000    310  190.000000
# 1    Feb  320.000000      b  264.000000
# 2    Mar  310.000000    330  247.000000
# 3    Apr  331.818182    345  245.272727
# 4    May  340.000000    350  285.000000
# 5    Jun  340.000000    326  346.000000
# 6    Jul  340.000000    378  145.000000
# 7    Aug  340.000000    416  265.000000
# 8    Sep  340.000000    NaN  218.000000
# 9    Oct  340.000000    342  312.000000
# 10   Nov  340.000000    259  170.000000
# 11   Dec  340.000000    298  256.000000

# %%
a=df.replace('b',320)

# %%
df['peach'].mean()
# Out:
# 245.27272727272725

# %%
a['banana'] =a['banana'].astype(float, errors = 'raise')

print(a.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   month   12 non-null     object
#  1   apple   12 non-null     float64
#  2   banana  11 non-null     float64
#  3   peach   12 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 512.0+ bytes
# None

# %%
a['banana'].fillna(a['peach'].mean(),inplace=True )

# %%
print(a)
# Out:
#    month       apple      banana       peach
# 0    Jan  300.000000  310.000000  190.000000
# 1    Feb  320.000000  320.000000  264.000000
# 2    Mar  310.000000  330.000000  247.000000
# 3    Apr  331.818182  345.000000  245.272727
# 4    May  340.000000  350.000000  285.000000
# 5    Jun  340.000000  326.000000  346.000000
# 6    Jul  340.000000  378.000000  145.000000
# 7    Aug  340.000000  416.000000  265.000000
# 8    Sep  340.000000  245.272727  218.000000
# 9    Oct  340.000000  342.000000  312.000000
# 10   Nov  340.000000  259.000000  170.000000
# 11   Dec  340.000000  298.000000  256.000000

# %% [markdown]
# ## 18.6 数据可视化复习

# %%
print(a['peach'])
# Out:
# 0     190.000000
# 1     264.000000
# 2     247.000000
# 3     245.272727
# 4     285.000000
# 5     346.000000
# 6     145.000000
# 7     265.000000
# 8     218.000000
# 9     312.000000
# 10    170.000000
# 11    256.000000
# Name: peach, dtype: float64

# %%
import matplotlib.pyplot as plt

a.plot(kind='bar',
        x = 'month',
       y=['apple', 'banana','peach'])
plt.show()

# %%
a.plot.box(y=['apple', 'banana','peach'])
plt.show()

# %%
a['apple']
# Out:
# 0     300.000000
# 1     320.000000
# 2     310.000000
# 3     331.818182
# 4     340.000000
# 5     340.000000
# 6     340.000000
# 7     340.000000
# 8     340.000000
# 9     340.000000
# 10    340.000000
# 11    340.000000
# Name: apple, dtype: float64

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
from pyecharts.globals import ThemeType

bar = ( 
    Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add_xaxis(['一月','二月','三月','四月','五月','六月','七月','八月','九月','十月','十一月','十二月'])
    .add_yaxis("苹果",  a['apple'].tolist())
    .add_yaxis("香蕉", a['banana'].tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="水果销量", subtitle="单位：斤数"))
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f59054ba034e4a018281a0da53c4c485" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f59054ba034e4a018281a0da53c4c485 = echarts.init(
#                     document.getElementById('f59054ba034e4a018281a0da53c4c485'), 'light', {renderer: 'canvas'});
#                 var option_f59054ba034e4a018281a0da53c4c485 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
# ...

# %%
import pyecharts.options as opts
from pyecharts.charts import Line

x= ['一月','二月','三月','四月','五月','六月','七月','八月','九月','十月','十一月','十二月']
y1= a['apple'].tolist()
y2=a['banana'].tolist()
y3=a['peach'].tolist()
line = (Line()
       .add_xaxis(x)
       .add_yaxis('苹果销量', y1)
       .add_yaxis('香蕉销量', y2)
       .add_yaxis('桃子销量', y3)
      )

line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ae366548c3d646b9ad0f1063cb4a6057" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ae366548c3d646b9ad0f1063cb4a6057 = echarts.init(
#                     document.getElementById('ae366548c3d646b9ad0f1063cb4a6057'), 'white', {renderer: 'canvas'});
#                 var option_ae366548c3d646b9ad0f1063cb4a6057 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %% [markdown]
# ## 编码

# %%
import pandas as pd

data = {
    '学历':['小学','中学','大学'],
    '数量': [1300,1320,1340]
}
xue=pd.DataFrame(data)
xue
# Out:
#    学历    数量
# 0  小学  1300
# 1  中学  1320
# 2  大学  1340

# %%
x= xue.iloc[:,0].values  

y =  xue .iloc[:,1].values  

x
# Out:
# array(['小学', '中学', '大学'], dtype=object)

# %%
y
# Out:
# array([1300, 1320, 1340], dtype=int64)

# %%
pd.get_dummies(x)
# Out:
#    中学  大学  小学
# 0   0   0   1
# 1   1   0   0
# 2   0   1   0

# %%
pd.get_dummies(xue)
# Out:
#      数量  学历_中学  学历_大学  学历_小学
# 0  1300      0      0      1
# 1  1320      1      0      0
# 2  1340      0      1      0

# %%
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder(sparse=False)

onehot = enc.fit_transform(xue[['学历']])

onehot
# Out:
# array([[0., 0., 1.],
#        [1., 0., 0.],
#        [0., 1., 0.]])

# %% [markdown]
# ## pandas数据可视化

# %%
import pandas as pd
df = pd.read_csv('fruit.csv',index_col=0)

df
# Out:
#        apple  banana  peach
# month
# Jan      300     310    190
# Feb      320     320    264
# Mar      310     330    247
# Apr      245     345    315
# May      340     350    285
# Jun      289     326    346
# Jul      340     378    145
# Aug      317     352    265
# Sep      356     249    218
# Oct      346     342    312
# Nov      346     259    170
# Dec      346     298    256

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.plot(y='apple')
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.plot.barh(stacked=True)
# Out:
# <AxesSubplot:ylabel='month'>

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.hist(stacked=True, bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.diff().hist()
# Out:
# array([[<AxesSubplot:title={'center':'apple'}>,
#         <AxesSubplot:title={'center':'banana'}>],
#        [<AxesSubplot:title={'center':'peach'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
df.plot.area()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.plot.area(stacked=False)
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.plot.scatter(x='apple', y='banana')
# Out:
# <AxesSubplot:xlabel='apple', ylabel='banana'>

# %%
df.plot.scatter(x='apple', y='banana',color="red", marker="*", s=100)
# Out:
# <AxesSubplot:xlabel='apple', ylabel='banana'>

# %%
df.plot.pie(subplots=True, figsize=(15, 15))
# Out:
# array([<AxesSubplot:ylabel='apple'>, <AxesSubplot:ylabel='banana'>,
#        <AxesSubplot:ylabel='peach'>], dtype=object)

# %% [markdown]
# ## 疫情数据分析

# %%
import pandas as pd

data = pd.read_csv('COVID.csv')

data
#Date日期，Daily Confirmed每日确诊，Total Confirmed	一共确诊，Daily Recovered每日康复，Daily Deceased每日死亡，Total Deceased一共死亡
# Out:
#              Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0     30 January                 1                1                0
# 1     31 January                 0                1                0
# 2    01 February                 0                1                0
# 3    02 February                 1                2                0
# 4    03 February                 1                3                0
# ..            ...              ...              ...              ...
# 100       09 May              3175            62865             1414
# 101       10 May              4311            67176             1669
# 102       11 May              3592            70768             1579
# 103       12 May              3562            74330             1905
# 104       13 May              3726            78056             1964
#
#      Total Recovered  Daily Deceased  Total Deceased
# 0                  0               0               0
# ...

# %%
C = data.iloc[70:,1].values #每日确诊Daily Confirmed
R = data.iloc[70:,3].values #每日康复Daily Recovered
D = data.iloc[70:,5].values #每日死亡Daily Deceased
X = data.iloc[70:,0] #日期Date

C  # 查看每日确诊数据后七十个
# Out:
# array([ 813,  871,  854,  758, 1243, 1031,  886, 1061,  922, 1371, 1580,
#        1239, 1537, 1292, 1667, 1408, 1835, 1607, 1568, 1902, 1705, 1801,
#        2396, 2564, 2952, 3656, 2971, 3602, 3344, 3339, 3175, 4311, 3592,
#        3562, 3726], dtype=int64)

# %%
import matplotlib.pyplot as plt

plt.plot(C)

# %%
from pylab import mpl
# mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.sans-serif'] = ['Microsoft YaHei']    
mpl.rcParams['axes.unicode_minus'] = False         


plt.figure(figsize=(20,10))
 
ax = plt.axes()  # 用于将坐标轴添加到当前图形并使其成为当前坐标轴
 
ax.set_facecolor("black")  # 设置背景颜色为黑色
ax.set_xlabel('日期',size=25)  # 设置横坐标和大小
ax.set_ylabel('确诊数量\n',
              size=25)
# 开始绘制X和C。颜色为红色
ax.plot(X,C,
        color='red',
        marker='o',
        linewidth=4,
        markersize=15
        )

# %% [markdown]
# ## 实战

# %%
import pandas as pd
df = pd.read_csv("data2.csv")
df.head(5)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
df[df.isnull().values==True]
# Out:
#     index  company body-style  wheel-base  length engine-type  \
# 22     31    isuzu      sedan        94.5   155.9         ohc
# 23     32    isuzu      sedan        94.5   155.9         ohc
# 47     63  porsche  hatchback        98.4   175.7       dohcv
#
#    num-of-cylinders  horsepower  average-mileage  price
# 22             four          70               38    NaN
# 23             four          70               38    NaN
# 47            eight         288               17    NaN

# %%
df.dropna()
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 0       0    alfa-romero  convertible        88.6   168.8        dohc
# 1       1    alfa-romero  convertible        88.6   168.8        dohc
# 2       2    alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3           audi        sedan        99.8   176.6         ohc
# 4       4           audi        sedan        99.4   176.6         ohc
# 5       5           audi        sedan        99.8   177.3         ohc
# 6       6           audi        wagon       105.8   192.7         ohc
# 7       9            bmw        sedan       101.2   176.8         ohc
# 8      10            bmw        sedan       101.2   176.8         ohc
# 9      11            bmw        sedan       101.2   176.8         ohc
# 10     13            bmw        sedan       103.5   189.0         ohc
# 11     14            bmw        sedan       103.5   193.8         ohc
# ...

# %%
m = df [['company','price']][df.price==df['price'].min()]
m
# Out:
#       company   price
# 13  chevrolet  5151.0

# %%
com = df.groupby('company')
ma = com.get_group('mazda')
ma
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 27     36   mazda  hatchback        93.1   159.1         ohc             four
# 28     37   mazda  hatchback        93.1   159.1         ohc             four
# 29     38   mazda  hatchback        93.1   159.1         ohc             four
# 30     39   mazda  hatchback        95.3   169.0       rotor              two
# 31     43   mazda      sedan       104.9   175.0         ohc             four
#
#     horsepower  average-mileage    price
# 27          68               30   5195.0
# 28          68               31   6095.0
# 29          68               31   6795.0
# 30         101               17  11845.0
# 31          72               31  18344.0

# %%
df[(df.company == 'mazda')]
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 27     36   mazda  hatchback        93.1   159.1         ohc             four
# 28     37   mazda  hatchback        93.1   159.1         ohc             four
# 29     38   mazda  hatchback        93.1   159.1         ohc             four
# 30     39   mazda  hatchback        95.3   169.0       rotor              two
# 31     43   mazda      sedan       104.9   175.0         ohc             four
#
#     horsepower  average-mileage    price
# 27          68               30   5195.0
# 28          68               31   6095.0
# 29          68               31   6795.0
# 30         101               17  11845.0
# 31          72               31  18344.0

# %%
df['company'].value_counts()
# Out:
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# mitsubishi       4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# honda            3
# isuzu            3
# jaguar           3
# porsche          3
# dodge            2
# volvo            2
# Name: company, dtype: int64

# %%
company= df.groupby('company')
min= company['company','price'].min()
min
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10768\3723810162.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   min= company['company','price'].min()
#                      company    price
# company
# alfa-romero      alfa-romero  13495.0
# audi                    audi  13950.0
# bmw                      bmw  16430.0
# chevrolet          chevrolet   5151.0
# dodge                  dodge   6229.0
# honda                  honda   7295.0
# isuzu                  isuzu   6785.0
# jaguar                jaguar  32250.0
# mazda                  mazda   5195.0
# mercedes-benz  mercedes-benz  25552.0
# mitsubishi        mitsubishi   5389.0
# nissan                nissan   6649.0
# porsche              porsche  34028.0
# toyota                toyota   5348.0
# volkswagen        volkswagen   7775.0
# volvo                  volvo  12940.0

# %%
price = df.sort_values(by=['price', 'horsepower'], ascending=False)
price.head()
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 35     47  mercedes-benz      hardtop       112.0   199.2        ohcv
# 11     14            bmw        sedan       103.5   193.8         ohc
# 34     46  mercedes-benz        sedan       120.9   208.1        ohcv
# 46     62        porsche  convertible        89.5   168.9        ohcf
# 12     15            bmw        sedan       110.0   197.0         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 35            eight         184               14  45400.0
# 11              six         182               16  41315.0
# 34            eight         184               14  40960.0
# 46              six         207               17  37028.0
# 12              six         182               15  36880.0

# %% [markdown]
# ## 实战案例二

# %%
import pandas as pd
df = pd.read_csv("stock .csv")
df.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2021-03-23  29008.019531  29043.179688  28376.220703  28497.380859
# 1  2021-03-24  28437.490234  28457.869141  27827.050781  27918.140625
# 2  2021-03-25  27628.080078  28032.009766  27505.080078  27899.609375
# 3  2021-03-26  28043.650391  28415.150391  28014.289063  28336.429688
# 4  2021-03-29  28317.320313  28484.660156  28132.359375  28338.300781
#
#       Adj Close      Volume
# 0  28497.380859  2049560300
# 1  27918.140625  2689142400
# 2  27899.609375  2595007600
# 3  28336.429688  2415384100
# 4  28338.300781  2847744100

# %%
import matplotlib.pyplot as plt

start_date = pd.to_datetime('2021-3-24') # 确定一个起始日期
end_date = pd.to_datetime('2021-05-24') # 确定一个结束日期                   
df['Date'] = pd.to_datetime(df['Date'])  # 读取数据表中的日期数据
new_df = (df['Date']>= start_date) & (df['Date']<= end_date) # 筛选范围内数据
df1 = df.loc[new_df] # 获取对应列
df2 = df1.set_index('Date')  # 横纵坐标样式绘制
plt.figure(figsize=(6,6))  # 窗口大小设定
plt.suptitle('历史股票数据', \
                 fontsize=18, color='blue')
plt.xlabel("Date",fontsize=16, color='black')
plt.ylabel("价格e", fontsize=16, color='black')
 
df2['Close'].plot(color='red'); # 按照闭盘价格绘制，颜色为红色
plt.show()

# %%
start_date = pd.to_datetime('2021-4-1') # s设置日期范围
end_date = pd.to_datetime('2021-4-30')                         
df['Date'] = pd.to_datetime(df['Date']) 
new_df = (df['Date']>= start_date) & (df['Date']<= end_date) # 筛选日期数据
df1 = df.loc[new_df] # 获取对应列
df2 = df1.set_index('Date') # 设置日期横坐标
plt.figure(figsize=(8,6)) # 窗口大小设置
plt.suptitle('股票交易条形图', fontsize=22, color='black') # 标题样式设置
plt.xlabel("Date",fontsize=16, color='black')# h横坐标样式设置
plt.ylabel("交易量", fontsize=16, color='black')  # 纵坐标样式设置
df2['Volume'].plot(color='red',kind='bar'); # 交易量条形图,红色条形
plt.show()

# %%
import seaborn as sns
start_date = pd.to_datetime('2021-4-1')
end_date = pd.to_datetime('2021-9-30')                         
df['Date'] = pd.to_datetime(df['Date']) 
new_df = (df['Date']>= start_date) & (df['Date']<= end_date)
df1 = df.loc[new_df]
df2 = df1[['Date', 'Adj Close']] 
df3 = df2.set_index('Date') # 日期为横坐标
plt.figure(figsize=(8,6)) # 窗口大小设置
daily_changes = df3.pct_change(periods=1) # 当前值和先前一个值之间的百分比变化。
sns.distplot(daily_changes['Adj Close'].dropna(),bins=100,color='red') # 以调整闭盘数据为准，对缺失值自动过滤
plt.suptitle('每日收益直方图', fontsize=12, color='black') # 标题设置
plt.grid(True) # 设置为True为添加网格
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
start_date = pd.to_datetime('2021-4-1')
end_date = pd.to_datetime('2021-9-30')                         
df['Date'] = pd.to_datetime(df['Date']) 
new_df = (df['Date']>= start_date) & (df['Date']<= end_date) # 筛选日期
df1 = df.loc[new_df]
stock_data = df1.set_index('Date') # 横坐标为日期
stock_data.plot(subplots = True, figsize = (9, 8)) # 绘制图形，使需要子图为真
plt.legend(loc = 'best') # 设置图标位置
plt.suptitle('股票数据绘制', fontsize=16, color='black')
plt.show()

# %% [markdown]
# ## 案例三

# %%
import pandas as pd
df = pd.read_csv("diamond.csv")
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df['price']
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 53940, dtype: int64

# %%
df.shape
# Out:
# (53940, 11)

# %%
df.cut.duplicated().sum() # duplicated () 函数返回表示重复行的布尔系列，sum计算和
# Out:
# 53935

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
df.groupby('clarity').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='clarity'>

# %%
data=df.iloc[:,1:]
data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
data.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
data.describe().corr()
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.999999  0.999999  0.947399  1.000000  1.000000  1.000000
# depth  0.999999  1.000000  1.000000  0.947535  0.999999  0.999999  0.999999
# table  0.999999  1.000000  1.000000  0.947641  0.999999  1.000000  1.000000
# price  0.947399  0.947535  0.947641  1.000000  0.947416  0.947687  0.947541
# x      1.000000  0.999999  0.999999  0.947416  1.000000  1.000000  1.000000
# y      1.000000  0.999999  1.000000  0.947687  1.000000  1.000000  1.000000
# z      1.000000  0.999999  1.000000  0.947541  1.000000  1.000000  1.000000

# %%
data.corr()
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %%
data.plot(kind='box', subplots=True, figsize=(30,30),layout=(3,4), sharex=False, sharey=False)
plt.show()
