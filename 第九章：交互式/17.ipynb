# %%
# !pip  install pyecharts
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\hp\anaconda3\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ##  直方图

# %%
from pyecharts.charts import Bar

bar = Bar()
bar.add_xaxis(["哈密瓜", "苹果", "西瓜", "香蕉", "猕猴桃", "菠萝"])
bar.add_yaxis("商店一周水果销售", [20, 30, 25, 35, 29, 36])

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2b2f57a091544001a6461b57c1845235" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2b2f57a091544001a6461b57c1845235 = echarts.init(
#                     document.getElementById('2b2f57a091544001a6461b57c1845235'), 'white', {renderer: 'canvas'});
#                 var option_2b2f57a091544001a6461b57c1845235 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
from pyecharts.charts import Bar

x = ["哈密瓜", "苹果", "西瓜", "香蕉", "猕猴桃", "菠萝"]
y =  [20, 30, 25, 35, 29, 36]


bar = (Bar()
       .add_xaxis(x)
       .add_yaxis('商店一周水果销售', y)
      )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c57ce0f5978d4f42bf55bf926f69c648" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c57ce0f5978d4f42bf55bf926f69c648 = echarts.init(
#                     document.getElementById('c57ce0f5978d4f42bf55bf926f69c648'), 'white', {renderer: 'canvas'});
#                 var option_c57ce0f5978d4f42bf55bf926f69c648 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
# !pip install black
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\hp\anaconda3\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

x = ["广东省", "江苏省", "浙江省", "河南省"]
y =  [12.44, 11.64,7.35, 5.8]


bar = (Bar()
       .add_xaxis(x)
       .add_yaxis('2021省份GDP', y)
       .set_global_opts(title_opts=opts.TitleOpts(title="经济", subtitle="单位：万亿"))
      )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="608b641677524609b8973073a2b53365" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_608b641677524609b8973073a2b53365 = echarts.init(
#                     document.getElementById('608b641677524609b8973073a2b53365'), 'white', {renderer: 'canvas'});
#                 var option_608b641677524609b8973073a2b53365 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
# pyecharts.globals.ThemeType内置好多种主题
from pyecharts.globals import ThemeType

bar = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add_xaxis(["哈密瓜", "苹果", "西瓜", "香蕉", "猕猴桃", "菠萝"])
    .add_yaxis("第一周",   [20, 30, 25, 35, 29, 36])
    .add_yaxis("第二周", [15, 25, 45, 37, 30, 40])
    .set_global_opts(title_opts=opts.TitleOpts(title="水果销量", subtitle="单位：斤数"))
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a06836fcacf543798c04ec3e077afed3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a06836fcacf543798c04ec3e077afed3 = echarts.init(
#                     document.getElementById('a06836fcacf543798c04ec3e077afed3'), 'light', {renderer: 'canvas'});
#                 var option_a06836fcacf543798c04ec3e077afed3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7b2c\u4e00\u5468",
#             "legendHoverLink": true,
# ...

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
# pyecharts.globals.ThemeType内置好多种主题
from pyecharts.globals import ThemeType

bar = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add_xaxis(["2016年", "2017年", "2018年", "2019年", "2020年", "2021年"])
    .add_yaxis("总人口",   [139232, 140011,140541, 141008, 141212, 141260])
    .add_yaxis("男性人口", [71307,71650,71864,72039,72357,72311])
    .add_yaxis("女性人口", [67925,68361,68677,68969,68855,68949])
    .set_global_opts(title_opts=opts.TitleOpts(title="中国五年人口数量变化", subtitle="单位：万人"))
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0137f839da0d41a3af3ea3c993db8b1d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0137f839da0d41a3af3ea3c993db8b1d = echarts.init(
#                     document.getElementById('0137f839da0d41a3af3ea3c993db8b1d'), 'light', {renderer: 'canvas'});
#                 var option_0137f839da0d41a3af3ea3c993db8b1d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u603b\u4eba\u53e3",
#             "legendHoverLink": true,
# ...

# %% [markdown]
# ## 箱形图

# %%
from pyecharts import options as opts
from pyecharts.charts import Boxplot

v1 = [
    [77,78,90,80,55,48,93,65,78,52],
    [79,80,85,81,44,63,79,95,76,85]
]
v2 = [
    [88,90,56,88,99,94,65,86,89,87],
    [78,98,55,68,98,53,64,38,79,94]
]
c = Boxplot()
c.add_xaxis(["语文", "数学"])
c.add_yaxis("语文", c.prepare_data(v1))
c.add_yaxis("数学", c.prepare_data(v2))
c.set_global_opts(title_opts=opts.TitleOpts(title="语文数学成绩对比"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="07f2eac3680243e7bf4f2506d2083b5e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_07f2eac3680243e7bf4f2506d2083b5e = echarts.init(
#                     document.getElementById('07f2eac3680243e7bf4f2506d2083b5e'), 'white', {renderer: 'canvas'});
#                 var option_07f2eac3680243e7bf4f2506d2083b5e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# ## 折线图

# %%
import pyecharts.options as opts
from pyecharts.charts import Line

x= ['苹果', '香蕉', '梨子', '哈密瓜', '桃子']
y= [55,65,46,41,38]

line = (Line()
       .add_xaxis(x)
       .add_yaxis('销量', y)
      )

line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9b5c4c92e3114360a2b3963bb63febca" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9b5c4c92e3114360a2b3963bb63febca = echarts.init(
#                     document.getElementById('9b5c4c92e3114360a2b3963bb63febca'), 'white', {renderer: 'canvas'});
#                 var option_9b5c4c92e3114360a2b3963bb63febca = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# ### 热力图·

# %%
from pyecharts.charts import Geo
from pyecharts import options as opts
from pyecharts.globals import ChartType

data=[('上海',43214.85),('北京',40269.60),('深圳',30664.85),('重庆',27894.02),('长沙',13270.70)]
geo = (Geo()
 .add_schema(maptype="china")
 .add("人口", data,
 type_=ChartType.HEATMAP)
 .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
 .set_global_opts(
 visualmap_opts=opts.VisualMapOpts(),
 legend_opts=opts.LegendOpts(is_show=False),
 title_opts=opts.TitleOpts(title="Geo-全国GDP图"))
 )
 
geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="ef1c41e3e62840a097ef8dd81ade68b2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_ef1c41e3e62840a097ef8dd81ade68b2 = echarts.init(
#                     document.getElementById('ef1c41e3e62840a097ef8dd81ade68b2'), 'white', {renderer: 'canvas'});
#                 var option_ef1c41e3e62840a097ef8dd81ade68b2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %% [markdown]
# ##  K线图

# %%
from pyecharts import options as opts
from pyecharts.charts import Kline

#开盘，关盘，最低价，最高价 
data = [
  [88.15,88.20,86.55,88.87],
    [88.35,88.26,87.10,89.72],
    [87.98,90.27,86.75,90.45],
    [90.19,92.31,90.07,93.17],
    [91.82,91.32,90.73,90.73],
    [89.86,89.66,88.43,90.58],
    [90.01,89.88,89.03,91.74],
    [90,93.10,89.19,94.66]
]

c = (
    Kline()
    .add_xaxis(["2022/2/{}".format(i+1) for i in range(8)])
    .add_yaxis("kline", data)
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(is_scale=True),
        yaxis_opts=opts.AxisOpts(
            is_scale=True,
            splitarea_opts=opts.SplitAreaOpts(
                is_show=True, areastyle_opts=opts.AreaStyleOpts(opacity=1)
            ),
        ),
        datazoom_opts=[opts.DataZoomOpts(pos_bottom="-2%")],
        title_opts=opts.TitleOpts(title="股票K线图绘制"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="935d4007105e4bfb840add3386a60e9a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_935d4007105e4bfb840add3386a60e9a = echarts.init(
#                     document.getElementById('935d4007105e4bfb840add3386a60e9a'), 'white', {renderer: 'canvas'});
#                 var option_935d4007105e4bfb840add3386a60e9a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# ## 饼图

# %%
from pyecharts.charts import Pie

x = ['一月', '二月', '三月', '四月', '五月', '六月']
y = [1500, 1400, 1350, 4130, 2120, 1520]

pie = (Pie()
       .add('', [list(z) for z in zip(x, y)])
       )

pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="769a42b2b8114007b55670d6793f57f1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_769a42b2b8114007b55670d6793f57f1 = echarts.init(
#                     document.getElementById('769a42b2b8114007b55670d6793f57f1'), 'white', {renderer: 'canvas'});
#                 var option_769a42b2b8114007b55670d6793f57f1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# ## 水球图

# %%
from pyecharts.charts import Liquid

liquid = (Liquid()
          .add("完成率", [0.18, 0.82])
          )

liquid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="2bec3776708b44d6b2b91e498fc4b28d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_2bec3776708b44d6b2b91e498fc4b28d = echarts.init(
#                     document.getElementById('2bec3776708b44d6b2b91e498fc4b28d'), 'white', {renderer: 'canvas'});
#                 var option_2bec3776708b44d6b2b91e498fc4b28d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
# ...

# %% [markdown]
# ##  地理坐标图

# %%
from pyecharts.charts import Geo

data=[('福建',41540086),('广东',126012510),('河北',74610235),('山西',34915616),('四川',83674866)]
print(data)
geo = (
    Geo()
    .add_schema(maptype="china")
    .add("", data)
)
geo.render_notebook()
# Out:
# [('福建', 41540086), ('广东', 126012510), ('河北', 74610235), ('山西', 34915616), ('四川', 83674866)]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="534b9eba0f054b79977163f865f17628" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_534b9eba0f054b79977163f865f17628 = echarts.init(
#                     document.getElementById('534b9eba0f054b79977163f865f17628'), 'white', {renderer: 'canvas'});
#                 var option_534b9eba0f054b79977163f865f17628 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
# ...

# %% [markdown]
# ## 16.3.2 地图

# %%
from pyecharts.charts import Map

data=[('福建',41540086),('广东',126012510),('河北',74610235),('山西',34915616),('四川',83674866)]
print(data)
geo = (
   Map()
  .add("", data, 'china')
)
geo.render_notebook()
# Out:
# [('福建', 41540086), ('广东', 126012510), ('河北', 74610235), ('山西', 34915616), ('四川', 83674866)]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="3ad8494194204701bdf13372bdb1fabe" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_3ad8494194204701bdf13372bdb1fabe = echarts.init(
#                     document.getElementById('3ad8494194204701bdf13372bdb1fabe'), 'white', {renderer: 'canvas'});
#                 var option_3ad8494194204701bdf13372bdb1fabe = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Map

data=[('宝山区',47885),('崇明区',1481),('奉贤区',24586),('虹口区',76440),('黄浦区',104092),
     ('嘉定区',45791),('静安区',45791),('金山区',19006),('闵行区',63119),('浦东新区',70526),
     ('普陀区',73322),('青浦区',44422),('松江区',39944),('徐汇区',96582),('杨浦区',76202),('长宁区',82854)]

geo =(
        Map()
        .add("", data, '上海')
    .set_global_opts(
            # 设置标题
            title_opts=opts.TitleOpts(title="上海市地图"),
            # 设置标准显示
            visualmap_opts=opts.VisualMapOpts(max_=1000, is_piecewise=False),
        )
    )

geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '上海':'https://assets.pyecharts.org/assets/maps/shanghai'
#         }
#     });
# </script>
#
#         <div id="362a378f7cda4d9cbb05de04bfe6a903" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '上海'], function(echarts) {
#                 var chart_362a378f7cda4d9cbb05de04bfe6a903 = echarts.init(
#                     document.getElementById('362a378f7cda4d9cbb05de04bfe6a903'), 'white', {renderer: 'canvas'});
#                 var option_362a378f7cda4d9cbb05de04bfe6a903 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %% [markdown]
# ##  人口输出图

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.globals import ChartType, SymbolType

c = (
    Geo()
    .add_schema(maptype="china")
    .add(
        "",
        [("广东",277.36), ("浙江", 246.59), ("江苏", 219.72), ("上海", 134.3),('北京',127.1)],
        type_=ChartType.EFFECT_SCATTER,
        color="white",
    )
    .add(
        "geo",
        [("河南", "广东"), ("河南", "浙江"), ("河南", "江苏"), ("河南", "上海"),('河南','北京')],
        type_=ChartType.LINES,
        effect_opts=opts.EffectOpts(
            symbol=SymbolType.ARROW, symbol_size=6, color="blue"
        ),
        linestyle_opts=opts.LineStyleOpts(curve=0.2),
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="河南省主要人口输出"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="3ae5fd23632449d4b6cc60f1368799f4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_3ae5fd23632449d4b6cc60f1368799f4 = echarts.init(
#                     document.getElementById('3ae5fd23632449d4b6cc60f1368799f4'), 'white', {renderer: 'canvas'});
#                 var option_3ae5fd23632449d4b6cc60f1368799f4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "white",
#         "#c23531",
#         "#2f4554",
# ...

# %% [markdown]
# ##   3D地图

# %%
from pyecharts import options as opts
from pyecharts.charts import Map3D
from pyecharts.globals import ChartType

data=[('福建',41540086),('广东',126012510),('河北',74610235),('山西',34915616),('四川',83674866),('新疆',2585.23)]

map3d = (
    Map3D()
    .add("部分省人口数量(单位：万)", data_pair=data, maptype='china')
)
map3d.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min'
#         }
#     });
# </script>
#
#         <div id="f36d3ac2943841028ff68f63f70cff7d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-gl'], function(echarts) {
#                 var chart_f36d3ac2943841028ff68f63f70cff7d = echarts.init(
#                     document.getElementById('f36d3ac2943841028ff68f63f70cff7d'), 'white', {renderer: 'canvas'});
#                 var option_f36d3ac2943841028ff68f63f70cff7d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
# ...

# %% [markdown]
# ##  3D地球

# %%
from pyecharts.faker import POPULATION
from pyecharts.charts import MapGlobe

globe = (
    MapGlobe()
    .add_schema()
    .add(
        series_name="",
        maptype="world",
        data_pair=POPULATION[1:]
    )
)

globe.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min', 'china':'https://assets.pyecharts.org/assets/maps/china', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#     <div id="b41c19a2aeb14712944550cc1aba0567" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-gl', 'china', 'world'], function(echarts) {
# 		var canvas_b41c19a2aeb14712944550cc1aba0567 = document.createElement('canvas');
#         var mapChart_b41c19a2aeb14712944550cc1aba0567 = echarts.init(
# 	    canvas_b41c19a2aeb14712944550cc1aba0567, 'white', {width: 4096, height: 2048, renderer: 'canvas'});
#         var mapOption_b41c19a2aeb14712944550cc1aba0567 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
# ...

# %%
from pyecharts.charts import Bar,Line

x = ['西红柿', '黄瓜', '白菜', '芹菜', '番茄', '土豆']
y = [7, 6, 5, 5.5, 6.5, 3]
z = [7.5, 5,6, 5, 6, 4]

# 绘制x与y数据
bar = (Bar()
       .add_xaxis(x)
       .add_yaxis('条形', y)
       )
# 绘制x与z数据
line = (Line()
        .add_xaxis(x)
        .add_yaxis('折线', z)
        )

geo= bar.overlap(line)
geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0aa645f7cdb54125b4cd7392e52c5219" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0aa645f7cdb54125b4cd7392e52c5219 = echarts.init(
#                     document.getElementById('0aa645f7cdb54125b4cd7392e52c5219'), 'white', {renderer: 'canvas'});
#                 var option_0aa645f7cdb54125b4cd7392e52c5219 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
from pyecharts.charts import Page, Grid
from pyecharts.charts import Bar,Line

x = ['西红柿', '黄瓜', '白菜', '芹菜', '番茄', '土豆']
y = [7, 6, 5, 5.5, 6.5, 3]
z = [7.5, 5,6, 5, 6, 4]

# 绘制x与y数据
bar = (Bar()
       .add_xaxis(x)
       .add_yaxis('条形', y)
       )
# 绘制x与z数据
line = (Line()
        .add_xaxis(x)
        .add_yaxis('折线', z)
        )

page = Page()
page.add(bar, line)
page.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5944994a1d4c49f382f90f3e1bec8486" style="width:900px; height:500px;"></div>
#         <div id="0c1c0a467e1745a5b41f2acbf9a9f6a2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5944994a1d4c49f382f90f3e1bec8486 = echarts.init(
#                     document.getElementById('5944994a1d4c49f382f90f3e1bec8486'), 'white', {renderer: 'canvas'});
#                 var option_5944994a1d4c49f382f90f3e1bec8486 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
# ...

# %%
from pyecharts.charts import Page, Grid
from pyecharts.charts import Bar,Line

x = ['西红柿', '黄瓜', '白菜', '芹菜', '番茄', '土豆']
y = [7, 6, 5, 5.5, 6.5, 3]
z = [7.5, 5,6, 5, 6, 4]

# 绘制x与y数据
bar = (Bar()
       .add_xaxis(x)
       .add_yaxis('条形', y)
       )
# 绘制x与z数据
line = (Line()
        .add_xaxis(x)
        .add_yaxis('折线', z)
        )
# 分别调节条形图与折线图参数
grid = (Grid()
        .add(bar,grid_opts=opts.GridOpts(pos_bottom="70%", pos_left="30%"))
        .add(line,grid_opts=opts.GridOpts(pos_left="15%"))
        )
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e1271ad3822d48acb7d7c5f973cefa46" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e1271ad3822d48acb7d7c5f973cefa46 = echarts.init(
#                     document.getElementById('e1271ad3822d48acb7d7c5f973cefa46'), 'white', {renderer: 'canvas'});
#                 var option_e1271ad3822d48acb7d7c5f973cefa46 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
from pyecharts.globals import ThemeType # 导入主题函数
from pyecharts.charts import Page, Grid
from pyecharts.charts import Bar,Line

x = ['西红柿', '黄瓜', '白菜', '芹菜', '番茄', '土豆']
y = [7, 6, 5, 5.5, 6.5, 3]
z = [7.5, 5,6, 5, 6, 4]

# 定义内置主题列表
all = ['chalk',
              'dark',
              'essos',
              'infographic',
              'light',
              'macarons',
              'purple-passion',
              'roma']
# 创建page对象
page = Page()
# 遍历每一个主题
for t in all:
    bar = (
        
        Bar(init_opts=opts.InitOpts(
            theme=t))
        .add_xaxis(x)
        .add_yaxis('品种', y)
        .add_yaxis('价格',z)
        .set_global_opts(title_opts=opts.TitleOpts("主题：{}".format(t)))
    )
    page.add(bar)

page.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'chalk':'https://assets.pyecharts.org/assets/themes/chalk', 'essos':'https://assets.pyecharts.org/assets/themes/essos', 'infographic':'https://assets.pyecharts.org/assets/themes/infographic', 'macarons':'https://assets.pyecharts.org/assets/themes/macarons', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion', 'roma':'https://assets.pyecharts.org/assets/themes/roma'
#         }
#     });
# </script>
#
#         <div id="446f62dba0054828bbf3533b19b897f8" style="width:900px; height:500px;"></div>
#         <div id="32b4057e454b416ea0610204883b394a" style="width:900px; height:500px;"></div>
#         <div id="efc82c195a114fb0874711fecd26216e" style="width:900px; height:500px;"></div>
#         <div id="415e795785d7483ab23fe58e8efc6093" style="width:900px; height:500px;"></div>
# ...

# %% [markdown]
# ## 图表样式

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

x = ["广东省", "江苏省", "浙江省", "河南省"]
y =  [12.44, 11.64,7.35, 5.8]

bar = (
    Bar()
    .add_xaxis(x)
    .add_yaxis('省份', y)
    .set_series_opts(
        # 关闭标签，如果不关闭会堆叠在一起
        label_opts=opts.LabelOpts(is_show=False),
        markpoint_opts=opts.MarkPointOpts(
            data=[
                opts.MarkPointItem(type_="max", name="最大值"),
                opts.MarkPointItem(type_="min", name="最小值"),
                opts.MarkPointItem(type_="average", name="平均值"),
            ]))
    .set_global_opts(title_opts=opts.TitleOpts("省份GDP条形图"))
)

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="feb53426d54145dc8413b65171768260" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_feb53426d54145dc8413b65171768260 = echarts.init(
#                     document.getElementById('feb53426d54145dc8413b65171768260'), 'white', {renderer: 'canvas'});
#                 var option_feb53426d54145dc8413b65171768260 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# ## 词云制作

# %%
import pyecharts.options as opts
from pyecharts.charts import WordCloud


data = [
    ("python", "999"),
    ("java", "888"),
    ("C++", "777"),
    ("C", "666"),
    ("mysql", "788"),
    ("sql", "516"),
    ("matlab", "515"),
    ("c#", "483")
]


globe=(
    WordCloud()
    .add(series_name="", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="热点分析", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
)
globe.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="df07938bad804d4f9bf7d9caf4488eaa" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_df07938bad804d4f9bf7d9caf4488eaa = echarts.init(
#                     document.getElementById('df07938bad804d4f9bf7d9caf4488eaa'), 'white', {renderer: 'canvas'});
#                 var option_df07938bad804d4f9bf7d9caf4488eaa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import WordCloud

words = [
    ("诸葛亮", 966),
    ("曹操", 939),
    ("刘备", 762),
    ("张飞", 357),
    ("吕布", 299),
    ("赵云", 294),
    ("典韦", 7),
    ("孙权", 260),
    ("周瑜", 244),
    ("司马懿", 234),
    ("袁绍", 206),
    ("关羽"  ,201),
    ("马超",188),
    ("黄忠",162),
    ("魏延",158),
    ("姜维",131),
    ("马岱",127),
    ("刘表",125),
    ("鲁肃",125),
    ("庞德" ,123),
     ("孟获",119)
]


c = (
    WordCloud()
    .add("", words, word_size_range=[12, 55], mask_image=r'1.jpg')
    .set_global_opts(title_opts=opts.TitleOpts(title="三国出现高频人物"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="417b31a9bb7c4501bde4c522d015ac85" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_417b31a9bb7c4501bde4c522d015ac85 = echarts.init(
#                     document.getElementById('417b31a9bb7c4501bde4c522d015ac85'), 'white', {renderer: 'canvas'});
#
#         var maskImage_5c9739987213411884a112c39940d5d6 = new Image();
#         maskImage_5c9739987213411884a112c39940d5d6.src = 'data:image/jpg;base64,...';
#
#                 var option_417b31a9bb7c4501bde4c522d015ac85 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
# ...

# %%
from pyecharts.charts import Map
from pyecharts import options as opts

data=[['香港', 328074], ['台湾', 56468], ['上海', 43782], ['吉林', 39903],
      ['浙江', 2984], ['黑龙江', 2851], ['广东', 6981], ['江西', 1184], 
      ['江苏', 2175], ['福建', 3002], ['山东', 2676], ['北京', 1876], 
      ['广西', 1572], ['山西', 413], ['海南', 288], ['青海', 88], 
      ['云南', 2114], ['四川', 1999], ['河南', 2878], ['湖南', 1362], 
      ['陕西', 3276], ['河北', 1993], ['内蒙古', 1706], ['安徽', 1063],
      ['辽宁', 1614], ['湖北', 68398], ['天津', 1800], ['重庆', 694], 
      ['贵州', 179], ['新疆', 999], ['甘肃', 681], ['宁夏', 122], 
      ['澳门', 82], ['西藏', 1]]

print(data)

geo = (
   Map()
  .add("感染人数", data, 'china') # 传入数据，地图选择中国

)
    
geo.render_notebook()
# Out:
# [['香港', 328074], ['台湾', 56468], ['上海', 43782], ['吉林', 39903], ['浙江', 2984], ['黑龙江', 2851], ['广东', 6981], ['江西', 1184], ['江苏', 2175], ['福建', 3002], ['山东', 2676], ['北京', 1876], ['广西', 1572], ['山西', 413], ['海南', 288], ['青海', 88], ['云南', 2114], ['四川', 1999], ['河南', 2878], ['湖南', 1362], ['陕西', 3276], ['河北', 1993], ['内蒙古', 1706], ['安徽', 1063], ['辽宁', 1614], ['湖北', 68398], ['天津', 1800], ['重庆', 694], ['贵州', 179], ['新疆', 999], ['甘肃', 681], ['宁夏', 122], ['澳门', 82], ['西藏', 1]]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="94e941c4af7d4398a8b3efea80d46808" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_94e941c4af7d4398a8b3efea80d46808 = echarts.init(
# ...

# %%
from pyecharts.charts import Map
from pyecharts import options as opts

data=[['香港', 328074], ['台湾', 56468], ['上海', 43782], ['吉林', 39903],
      ['浙江', 2984], ['黑龙江', 2851], ['广东', 6981], ['江西', 1184], 
      ['江苏', 2175], ['福建', 3002], ['山东', 2676], ['北京', 1876], 
      ['广西', 1572], ['山西', 413], ['海南', 288], ['青海', 88], 
      ['云南', 2114], ['四川', 1999], ['河南', 2878], ['湖南', 1362], 
      ['陕西', 3276], ['河北', 1993], ['内蒙古', 1706], ['安徽', 1063],
      ['辽宁', 1614], ['湖北', 68398], ['天津', 1800], ['重庆', 694], 
      ['贵州', 179], ['新疆', 999], ['甘肃', 681], ['宁夏', 122], 
      ['澳门', 82], ['西藏', 1]]

print(data)

geo = (
   Map()
  .add("感染人数", data, 'china') # 传入数据，地图选择中国
  .set_global_opts(
    title_opts=opts.TitleOpts(title="2022-4-23中国疫情地图"),
    visualmap_opts=opts.VisualMapOpts(max_=10000, is_piecewise=True,
                                    #最大数据范围，分段
                                    # 第一段设置为：猩红
                                      pieces=[
                                          {"max": 99999, "min": 10001, "label": ">10000", "color": "#DC143C"},
                                          {"max": 10000, "min": 1000, "label": "1000-10000", "color": "#8A0808"},
                                          {"max": 999, "min": 500, "label": "500-999", "color": "#B40404"},
                                          {"max": 499, "min": 100, "label": "100-499", "color": "#DF0101"},
                                          {"max": 99, "min": 10, "label": "10-99", "color": "#F78181"},
                                          {"max": 9, "min": 1, "label": "1-9", "color": "#F5A9A9"},
                                          {"max": 0, "min": 0, "label": "0", "color": "#FFFFFF"},
                                      ],
                                     is_calculable=True) 
)
)
    
geo.render_notebook()
# Out:
# [['香港', 328074], ['台湾', 56468], ['上海', 43782], ['吉林', 39903], ['浙江', 2984], ['黑龙江', 2851], ['广东', 6981], ['江西', 1184], ['江苏', 2175], ['福建', 3002], ['山东', 2676], ['北京', 1876], ['广西', 1572], ['山西', 413], ['海南', 288], ['青海', 88], ['云南', 2114], ['四川', 1999], ['河南', 2878], ['湖南', 1362], ['陕西', 3276], ['河北', 1993], ['内蒙古', 1706], ['安徽', 1063], ['辽宁', 1614], ['湖北', 68398], ['天津', 1800], ['重庆', 694], ['贵州', 179], ['新疆', 999], ['甘肃', 681], ['宁夏', 122], ['澳门', 82], ['西藏', 1]]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="6959cf716f374e7fa0acecdb0b204d10" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_6959cf716f374e7fa0acecdb0b204d10 = echarts.init(
# ...

# %%
from pyecharts.charts import Map
from pyecharts import options as opts


attr_1= [95, 56, 87, 92, 74, 79, 82,68 , 59, 63, 82]
value_1  = ["福建","河南","浙江","江西","贵州","四川","上海","北京","湖北","广西","河北"]
# print([list(z) for z in zip(attr_1, value_1)])

c = (
    Map()
    .add("空气质量", [list(z) for z in zip(attr_1, value_1)],"china") # 用列表推导式对两个列表合并成对应形式

    .set_global_opts(
        title_opts=opts.TitleOpts(title="降雨量可视化"),
        visualmap_opts=opts.VisualMapOpts(max_=100,is_piecewise=True                              
                                    )
    )
)
# c.render_notebook()
c.render(r"1.html")
# Out:
# 'C:\\Users\\hp\\Desktop\\spyder\\交互式\\1.html'

# %%
from pyecharts import options as opts


value_1 = [1500, 1300, 20000, 23000, 3500, 3400, 2500]
attr_1 = ["福建","山东","北京","上海","江西","云南","重庆"]
value_2 = [21000, 16520, 24120, 17820, 9542, 4689, 4325, 8950,]
attr_2 = ["北京","广东","上海","浙江","四川","贵州","云南","重庆"]

c = (
    Map()
    .add("饿了么", [list(z) for z in zip(attr_1, value_1)],"china")
    .add("美团", [list(z) for z in zip(attr_2, value_2)],"china")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="美团-饿了么骑手分布"),
        visualmap_opts=opts.VisualMapOpts(max_=25000,is_piecewise=True)
    )
)


# c.render_notebook()
c.render(r"2.html")
# Out:
# 'C:\\Users\\hp\\Desktop\\spyder\\交互式\\2.html'
